# %%
library(Seurat)

rds_path <- list.files(pattern = "*.RDS")

# %%
seurat <- readRDS(rds_path)
seurat
# Out:
# An object of class Seurat
# 541 features across 36602 samples within 4 assays
# Active assay: Xenium (248 features, 248 variable features)
#  3 layers present: counts, data, scale.data
#  3 other assays present: BlankCodeword, ControlCodeword, ControlProbe
#  3 dimensional reductions calculated: xenium_umap, pca, umap
#  1 spatial field of view present: fov

# %%
DimPlot(object = seurat, reduction = "umap")
# Out:
# plot without title

# %%
DimPlot(object = seurat, reduction = "xenium_umap")
# Out:
# Warning message:
# “Removing 49 cells missing data for vars requested”
# plot without title
